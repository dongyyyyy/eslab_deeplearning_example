# %% [markdown]
# ### Fully-connected Layer(Dense Layer)
# ## $H(x) = Wx + b$
# ### - x = [1,2,3]
# ### - y = [1,2,3]

# %%
import numpy as np
import torch
import torch.nn as nn

# %%
class model(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1,1,bias=True)
    def forward(self,x):
        return self.linear(x)

# %%
class model_parameter(nn.Module):
    def __init__(self):
        super().__init__()
        self.W = nn.Parameter(torch.rand(1,1),requires_grad=True)
        self.B = nn.Parameter(torch.rand(1,1),requires_grad=True)
        
    def forward(self,x):
        return ((self.W * x) + self.B)

# %%
model1 = model()
model2 = model_parameter()

# %%
x_train = torch.tensor(np.array([1,2,3]).reshape(-1,1),dtype=torch.float)
y_train = torch.tensor(np.array([1,2,3]).reshape(-1,1))

# %% [markdown]
# # Cost or Loss function
# ## $cost(W,b) = \frac{1}{m} \sum_{i=1}^{m} {(H(x^{(i)})-y^{(i)})^2}$

# %%
class mean_squred_error(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self,x,y):
        return torch.mean(torch.square(x-y))

# %%
cost = mean_squred_error()

# %% [markdown]
# ## Optimizer (Stochastic Gradient Descent)
# ### $\theta = \theta - \eta \nabla_{\theta}J(\theta)$

# %%
learning_rate = 0.01
optim1 = torch.optim.SGD(model1.parameters(),lr=learning_rate)
optim2 = torch.optim.SGD(model2.parameters(),lr=learning_rate)

# %%
epochs = 1000

# %%
check_gradient = False
saved_loss1 = []
for epoch in range(epochs):
    '''
    optim1.zero_grad()는 무엇을 하는 작업인가?
    '''
#     if check_gradient == False:
#         print('before zero.grad() : ', model1.linear.weight.grad)
    optim1.zero_grad()
#     if check_gradient == False:
#         print('after zero.grad() : ', model1.linear.weight.grad)
#         check_gradient = True
    
    pred = model1(x_train)
    
    loss = cost(pred,y_train)
    saved_loss1.append(loss.item())
    
    '''
    아래의 loss.backward() 와 optim.step() 이 의미하는 바는?
    '''
#     print('before back-propagation() : ', model1.linear.weight.grad)
#     print(f'before back-propagation : {model1.linear.weight[0]}')
    loss.backward()
#     print('after back-propagation() : ', model1.linear.weight.grad)
#     print(f'before update(step) : {model1.linear.weight[0]}')
    optim1.step()
#     print(f'after update(step) : {model1.linear.weight[0]}')
# Out:
# before back-propagation : tensor([0.0241], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.0241], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.1259], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.1259], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.1259], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.2163], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.2163], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.2163], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.2968], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.2968], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.2968], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.3683], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.3683], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.3683], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.4319], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.4319], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.4319], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.4885], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.4885], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.4885], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.5388], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.5388], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.5388], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.5836], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.5836], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.5836], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.6234], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.6234], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.6234], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.6588], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.6588], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.6588], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.6903], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.6903], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.6903], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.7183], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.7183], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.7183], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.7432], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.7432], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.7432], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.7654], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.7654], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.7654], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.7851], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.7851], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.7851], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8026], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8026], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8026], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8183], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8183], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8183], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8322], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8322], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8322], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8445], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8445], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8445], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8556], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8556], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8556], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8654], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8654], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8654], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8741], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8741], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8741], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8819], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8819], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8819], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8888], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8888], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8888], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.8950], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.8950], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.8950], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9005], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9005], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9005], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9054], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9054], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9054], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9098], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9098], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9098], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9137], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9137], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9137], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9172], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9172], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9172], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9203], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9203], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9203], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9231], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9231], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9231], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9256], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9256], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9256], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9278], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9278], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9278], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9298], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9298], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9298], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9316], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9316], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9316], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9332], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9332], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9332], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9347], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9347], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9347], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9360], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9360], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9360], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9372], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9372], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9372], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9382], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9382], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9382], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9392], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9392], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9392], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9400], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.
grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9611], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9611], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9612], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9612], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9612], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9612], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9612], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9612], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9613], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9613], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9613], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9614], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9614], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9614], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9615], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9615], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9615], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9616], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9616], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9616], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9617], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9617], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9617], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9618], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9618], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9618], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9619], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9619], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9619], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9620], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9620], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9620], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9621], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9621], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9621], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9622], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9622], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9622], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9623], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9623], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9623], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9623], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9623], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9623], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9624], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9624], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9624], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9625], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9625], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9625], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9626], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9626], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9626], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9627], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9627], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9627], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9628], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9628], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9628], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9629], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9629], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9629], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9630], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9630], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9630], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9631], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9631], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9631], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9632], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9632], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9632], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9632], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9632], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9632], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9633], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9633], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9633], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9634], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9634], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9634], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9635], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9635], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9635], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9636], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9636], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9636], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9637], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9637], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9637], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9638], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9638], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9638], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9639], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9639], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9639], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9639], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9639], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9639], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9640], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9640], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9640], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9641], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9641], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9641], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9642], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9642], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9642], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9643], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9643], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9643], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9644], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9644], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9644], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9645], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9645], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9645], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9645], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9645], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9645], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9646], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9646], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9646], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9647], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9647], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9647], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9648], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9648], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9648], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9649], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9649], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9649], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9650], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9650], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9650], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9651], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9651], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9651], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9651], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9651], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9651], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9652], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9652], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9652], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9653], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9653], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9653], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9654], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9654], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9654], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9655], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9655], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9655], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9656], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9656], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9656], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9656], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9656], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9656], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9657], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9657], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9657], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9658], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9658], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9658], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9659], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9659], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9659], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9660], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9660], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9660], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9660], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9660], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9660], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9661], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9661], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9661], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9662], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9662], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9662], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9663], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9663], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9663], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9664], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9664], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9664], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9665], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9665], grad_fn=<SelectBackward>)
# ...
# before update(step) : tensor([0.9934], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9934], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9934], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9934], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9935], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9935], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9935], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9935], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9935], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9935], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9935], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9935], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9936], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9936], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9936], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9936], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9936], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9936], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9936], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9937], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9937], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9937], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9937], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9937], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9937], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9937], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9937], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9938], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9938], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9938], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9938], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9938], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9938], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9938], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9939], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9939], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9939], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9939], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9939], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9939], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9939], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9939], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9940], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9940], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9940], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9940], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9940], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9940], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9940], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9940], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9941], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9941], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9941], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9941], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9941], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9941], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9941], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9941], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9942], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9942], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9942], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9942], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9942], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9942], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9942], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9942], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9943], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9943], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9943], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9943], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9943], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9943], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9943], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9943], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9943], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9944], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9944], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9944], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9944], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9944], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9944], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9944], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9944], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9945], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9945], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9945], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9945], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9945], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9945], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9945], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9945], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9945], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9946], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9946], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9946], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9946], grad_fn=<SelectBackward>)
# before back-propagation : tensor([0.9946], grad_fn=<SelectBackward>)
# before update(step) : tensor([0.9946], grad_fn=<SelectBackward>)
# after update(step) : tensor([0.9946], grad_fn=<SelectBackward>)

# %%
print(model1.linear.weight,model1.linear.bias)
# Out:
# Parameter containing:
# tensor([[0.9683]], requires_grad=True) Parameter containing:
# tensor([0.0721], requires_grad=True)

# %%
saved_loss2 = []
for epoch in range(epochs):
    optim2.zero_grad()
    
    pred = model2(x_train)
    
    loss = cost(pred,y_train)
    saved_loss2.append(loss.item())
    loss.backward()
    optim2.step()

# %%
print(model2.W, model2.B)
# Out:
# Parameter containing:
# tensor([[0.9581]], requires_grad=True) Parameter containing:
# tensor([[0.0953]], requires_grad=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(saved_loss1,label='nn.Linear model')
plt.plot(saved_loss2,label='Parameter model')
plt.legend()
plt.show()

# %%
print(f'Linear layer weights : {model1.linear.weight} Linear layer bias : {model1.linear.bias}')
print(f'Linear layer weights : {model2.W} Linear layer bias : {model2.B}')
# Out:
# Linear layer weights : Parameter containing:
# tensor([[0.9683]], requires_grad=True) Linear layer bias : Parameter containing:
# tensor([0.0721], requires_grad=True)
# Linear layer weights : Parameter containing:
# tensor([[0.9581]], requires_grad=True) Linear layer bias : Parameter containing:
# tensor([[0.0953]], requires_grad=True)

# %% [markdown]
# ## Our Goal $\rightarrow$ $W \approx 1$ and $B \approx 0$
